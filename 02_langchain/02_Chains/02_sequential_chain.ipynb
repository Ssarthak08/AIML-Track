# %%
a = """Hi Tanishpreet,\n\nI noted TK Limited's mission since 2020 to automate and aggregate shipping solutions across your operations in the USA, Canada, and India. It's a significant goal given the evolving freight landscape.\n\nTeams in transportation and logistics often deal with the complexity of truly automating and aggregating shipping solutions. This can sometimes make it challenging to ensure small family-based trucking companies access higher profit margins and best-in-class shipping experiences.\n\nAre you finding it difficult to consistently provide shippers with the reliable, cost-effective logistics solutions and real-time visibility they require? Our 34+ years helping logistics providers streamline operations with tailored digital products and advanced automation has offered valuable insights into overcoming these specific hurdles.\n\nWould you be open to a brief 10-minute conversation next week to explore potential solutions for these challenges?\n\nBest regards,\nSatnam Singh Thakur"""

# %%
from bs4 import BeautifulSoup

html = a  # your input string

soup = BeautifulSoup(html, "html.parser")

text = soup.get_text()
print(text)
# Out:
# Hi Tanishpreet,
#
# I noted TK Limited's mission since 2020 to automate and aggregate shipping solutions across your operations in the USA, Canada, and India. It's a significant goal given the evolving freight landscape.
#
# Teams in transportation and logistics often deal with the complexity of truly automating and aggregating shipping solutions. This can sometimes make it challenging to ensure small family-based trucking companies access higher profit margins and best-in-class shipping experiences.
#
# Are you finding it difficult to consistently provide shippers with the reliable, cost-effective logistics solutions and real-time visibility they require? Our 34+ years helping logistics providers streamline operations with tailored digital products and advanced automation has offered valuable insights into overcoming these specific hurdles.
#
# Would you be open to a brief 10-minute conversation next week to explore potential solutions for these challenges?
#
# Best regards,
# ...

# %%
import markdown
# print(markdown.markdown(a, extensions=["nl2br"]))
print(markdown.markdown(a))
# Out:
# <p>Hi Tanishpreet,</p>
# <p>I noted TK Limited's mission since 2020 to automate and aggregate shipping solutions across your operations in the USA, Canada, and India. It's a significant goal given the evolving freight landscape.</p>
# <p>Teams in transportation and logistics often deal with the complexity of truly automating and aggregating shipping solutions. This can sometimes make it challenging to ensure small family-based trucking companies access higher profit margins and best-in-class shipping experiences.</p>
# <p>Are you finding it difficult to consistently provide shippers with the reliable, cost-effective logistics solutions and real-time visibility they require? Our 34+ years helping logistics providers streamline operations with tailored digital products and advanced automation has offered valuable insights into overcoming these specific hurdles.</p>
# ...
