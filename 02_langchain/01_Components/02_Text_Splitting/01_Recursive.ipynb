# %% [markdown]
# ### Text Splitting from Documents

# %%
from langchain_community.document_loaders import PyMuPDFLoader
Loader_1 = PyMuPDFLoader('501_word_paragraph.pdf')  # loader was created over here 
Loader_1
Doc = Loader_1.load()   # at this step the document was created and it returns a list over here, page-1 to 500, each page is document
type(Doc[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# #### Recursive text splitter technique

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter  = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap =50)
final_documents=text_splitter.split_documents(Doc)
final_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-04T06:53:59+00:00', 'source': '501_word_paragraph.pdf', 'file_path': '501_word_paragraph.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-04T06:53:59+00:00', 'trapped': '', 'modDate': "D:20260204065359+00'00'", 'creationDate': "D:20260204065359+00'00'", 'page': 0}, page_content='Artificial intelligence has rapidly evolved from a theoretical concept into a practical force that shapes\nmodern society, influencing how people work, communicate, and make decisions. At its core,\nartificial intelligence refers to systems designed to simulate human intelligence by learning from\ndata, recognizing patterns, and making informed predictions or decisions. Over the past decade,\nadvances in computing power, availability of large-scale data, and improvements in 
# ...

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='Artificial intelligence has rapidly evolved from a theoretical concept into a practical force that shapes
# modern society, influencing how people work, communicate, and make decisions. At its core,
# artificial intelligence refers to systems designed to simulate human intelligence by learning from
# data, recognizing patterns, and making informed predictions or decisions. Over the past decade,
# ...
